# %%
from openai import OpenAI

# %%
# Point to your local llama.cpp server
client = OpenAI(
    base_url="http://localhost:8080/v1", 
    api_key="sk-no-key-required"  # Standard placeholder for local servers
)

# %%
response = client.chat.completions.create(
    model="sarvam/sarvam-30b",
    messages=[{"role": "user", "content": "How do I use a local LLM in Jupyter?"}]
)

# %%
print(response.choices[0].message.content)
# Out:
# Of course! Using a local LLM in Jupyter is a fantastic way to experiment, build projects, and keep your data private. Here’s a comprehensive guide, from a quick start to detailed explanations.
#
# ### Quick Start: The Easiest Path (Recommended for most users)
#
# If you want the fastest and simplest way, **Oobabooga's Text Generation Web UI** is a great choice. It has a simple interface and works well with Jupyter.
#
# 1.  **Install:** Download and run the [Oobabooga installer](https://github.com/oobabooga/text-generation-webui/blob/main/README_install.md) from its GitHub page. Follow the instructions for your operating system.
# 2.  **Run:** Open your terminal and run:
#     ```bash
#     python server.py
#     ```
# 3.  **Connect:** Open a new terminal, activate your virtual environment (if you created one), and run:
#     ```bash
#     text-generation-webui
#     ```
# ...
